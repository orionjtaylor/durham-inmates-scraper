# %% [markdown]
# ### Package Imports

# %%
# Package imports
import pandas as pd
import numpy as np
import selenium
from selenium import webdriver
from bs4 import BeautifulSoup

# %% [markdown]
# ### Initial Scrape (to Pandas MultiIndex)

# %%
# Define primary source URL and driver path
primary_url = 'http://www2.durhamcountync.gov/sheriff/ips/default.aspx'
driver = webdriver.Chrome(executable_path='/Users/orion/Downloads/chromedriver')

# Initiate page and change table view to 'Incarcerated' (automatic view is 'Last 24 hours')
driver.get(primary_url)
driver.find_element_by_xpath('//*[@id="ddlDateListing"]/option[3]').click()

# Parse HTML using BS4 and close browser
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
driver.close()

# %%
# Initiate dictionary of inmates and lists of offenses; isolate table
offenses_list = []
inmate_dictionary = {}
table = soup.find('table', id='Table1')
rows = table.find_all('tr')
stripchars = '][\'\"'

# For each inmate row, append data to list
for row in rows:
    data = row.find_all('td')
    data = [element.text.strip() for element in data]
    offenses_list.append([element for element in data if element])

# For each list, set inmate name as key and format as dictionary ({Name: [[Offense 1], [Offense 2],...]...})
for element in offenses_list:
    if len(element) == 1:
        inmate_dictionary[str(element).lstrip(stripchars).rstrip(stripchars)] = []
        last_offender = str(element).lstrip(stripchars).rstrip(stripchars)
    elif (len(element) != 1) & ('D' not in element[0]):
        inmate_dictionary[last_offender].extend([element])

# %%
# Convert dictionary into cleaned MultiIndex DataFrame
series = pd.concat({key.replace(',', ''): pd.Series(value) for key, value in inmate_dictionary.items()})
transition_dataframe = pd.DataFrame(series, columns=['Incidents'])
offenses = transition_dataframe['Incidents'].apply(pd.Series)
offenses.columns=['Date Confined', 'Date Charged', 
                 'Date Released', 'Statute Description', 
                 'Bond Type', 'Bond Amount', 'Court Docket', 
                 'Days in Jail/Charge']
offenses.index.levels[0].name = 'Name'

# %% [markdown]
# ### Secondary Scrape (demographic data from hyperlinks)

# %%
# Initiate list of hyperlinks and dictionary of additional data
secondary_urls = []
demographics_dictionary = {}

# Populate list of hyperlinks from NC SAVAN/VINELink
for anchor in soup.findAll('a', href=True):
    secondary_urls.append(anchor['href'])   
secondary_urls = secondary_urls[2:-1]

# %%
# Define function to check for presence of xpath
def hasxpath(xpath):
    try: 
        driver.find_element_by_xpath(xpath)
        return True
    except:
        return False

# %%
# For each hyperlinked URL, initiate page and wait 3 seconds

for url in url_list:
    driver = webdriver.Chrome('D:/Java/TestChrome/lib/chromedriver.exe')
    print(url)
    driver.get(url)
    time.sleep(3)
    if hasxpath('xxx') == True:

        if hasxpath('xxx') == True:
            driver.find_element_by_xpath('xxx').click()

            # For each field, check if it exists and if so collect data
            # (example below for 'Name' field)
            if hasxpath('xxx') == True:
                name = driver.find_element_by_xpath('xxx')
                name = name.text
            else:
                name = ''
            driver.close()

        else:
            driver.close()

    else:
        driver.close()
        print('Closing Browser : ' + url)

print('pass') 






for url in secondary_urls:
    driver = webdriver.Chrome(executable_path='/Users/orion/Downloads/chromedriver')
    print(url)
    driver.get(url)
    time.sleep(3)
    # driver.implicitly_wait(2)
    
    # If search result page exists, continue, else close driver
    if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[1]/span[1]/div/div/div[2]/span') == True:
        name = driver.find_element_by_xpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[1]/span[1]/div/div/div[2]/span')
        
        # For each datum, if information exists, collect, else set blank
        
        
        # If 'More Info' button exists, expand page and collect additional data
        if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[4]/div[1]/more-info/div[1]/button') == True:
            driver.find_element_by_xpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[4]/div[1]/more-info/div[1]/button').click()
           
            # For each datum, if information exists, collect, else set blank
            if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[10]/div/div/div[2]/span') == True:
                age = driver.find_element_by_xpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[10]/div/div/div[2]/span')
                age = age.text
            else:
                age = ''
            if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[5]/div/div/div[2]/span') == True:
                custodystatus = driver.find_element_by_xpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[5]/div/div/div[2]/span')
                custodystatus = custodystatus.text
            else:
                custodystatus = ''
            if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[14]/div/div/div[2]/span') == True:
                race = driver.find_element_by_xpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[14]/div/div/div[2]/span')
                race = race.text
            else:
                race = ''
            if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[4]/div[1]/more-info/div[2]/div/div/div[2]/div[1]/div/div[2]/span') == True:
                offenderid = driver.find_element_by_xpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[4]/div[1]/more-info/div[2]/div/div/div[2]/div[1]/div/div[2]/span')
                offenderid = offenderid.text
            else:
                offenderid = ''
            if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[4]/div[1]/more-info/div[2]/div/div/div[2]/div[2]/div/div[2]/span') == True:
                gender = driver.find_element_by_xpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[4]/div[1]/more-info/div[2]/div/div/div[2]/div[2]/div/div[2]/span')
                gender = gender.text
            else:
                gender = ''
            if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[4]/div[1]/more-info/div[2]/div/div/div[2]/div[4]/div/div[2]/span') == True:
                dob = driver.find_element_by_xpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[4]/div[1]/more-info/div[2]/div/div/div[2]/div[4]/div/div[2]/span')
                dob = dob.text
            else:
                dob = ''
        
            demographics_dictionary[name] = [offenderid, age, dob, race, gender, custodystatus]
            driver.close()
            
        else:
            offenderid = ''
            dob = ''
            gender = ''
            
            if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[1]/span[1]/div/div/div[2]/span') == True:
                name = driver.find_element_by_xpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[1]/span[1]/div/div/div[2]/span')
                name = name.text
            else:
                name = ''
            if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[10]/div/div/div[2]/span') == True:
                age = driver.find_element_by_xpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[10]/div/div/div[2]/span')
                age = age.text
            else:
                age = ''
            if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[5]/div/div/div[2]/span') == True:
                custodystatus = driver.find_element_by_xpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[5]/div/div/div[2]/span')
                custodystatus = custodystatus.text
            else:
                custodystatus = ''
            if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[14]/div/div/div[2]/span') == True:
                race = driver.find_element_by_xpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[14]/div/div/div[2]/span')
                race = race.text
            else:
                race = ''
            
            demographics_dictionary[name] = [offenderid, age, dob, race, gender, custodystatus]
            driver.close()
            
    else:
        driver.close()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-7-d4b6569f2776> in <module>()
#      10         # If 'More Info' button exists, expand page and collect additional data
#      11         if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[4]/div[1]/more-info/div[1]/button') == True:
# ---> 12             driver.find_element_by_xpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[4]/div[1]/more-info/div[1]/button').click()
#      13
#      14             if hasxpath('//*[@id="ngVewDiv"]/div/div/div/div[3]/div[3]/div[2]/div/search-result/div/div[1]/div/div[1]/span[1]/span[1]/div/div/div[2]/span') == True:
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: Element <button type="button" class="btn btn-link underlineLinkMoreInfo ng-binding" ng-click="showAdvanced_$index = !showAdvanced_$index; moreInfoCall(showAdvanced_$index);">...</button> is not clickable at point (92, 370). Other element would receive the click: <span class="us-spinner-wrapper ng-scope" us-spinner="{radius:30, width:8, length: 16, shadow: true}">...</span>
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.44.609545 (c2f88692e98ce7233d2df7c724465ecacfe74df5),platform=Mac OS X 10.14.2 x86_64)

# %%
# Strip commas from names so they share format with offenses dataframe
demographics_dictionary = {key.replace(',', ''): item for key, item in demographics_dictionary.items()}

# Convert demographic information into DataFrame and assign column names
demographics = pd.DataFrame.from_dict(demographics_dictionary, 'index')
demographics.columns = ['Offender ID', 'Age', 'Date of Birth', 'Race', 'Gender', 'Custody Status']
demographics.index.name = 'Name'

# %% [markdown]
# ### Data Merge and Export

# %%
# Join offenses and demographics to create final MultiIndex DataFrame
final = offenses.join(demographics)

# %%
final
# Out:
#                               Date Confined Date Charged   Date Released  \
# Name
# ALLEN CHRISTOPHER LEE      0      8/20/2018    8/20/2018  [incarcerated]
#                            1      8/20/2018    8/20/2018  [incarcerated]
#                            2      8/20/2018    8/20/2018  [incarcerated]
#                            3      8/20/2018    8/20/2018  [incarcerated]
#                            4      8/20/2018    8/20/2018  [incarcerated]
#                            5      8/20/2018    8/20/2018  [incarcerated]
# ALSTON LADRRIOUS LAMONTE   0      11/1/2018    11/1/2018  [incarcerated]
#                            1      11/1/2018    11/1/2018  [incarcerated]
#                            2      11/1/2018    11/1/2018  [incarcerated]
#                            3      11/1/2018    11/1/2018  [incarcerated]
#                            4      11/1/2018    11/1/2018  [incarcerated]
#                            5      11/1/2018    11/1/2018  [incarcerated]
#                            6      11/1/2018    11/1/2018  [incarcerated]
# ALSTON MARCELLAS ALEXANDER 0      9/19/2018    9/19/2018  [incarcerated]
#                            1      9/19/2018    9/19/2018  [incarcerated]
# ALSTON SCOTT DELANTA       0      1/15/2019    1/15/2019  [incarcerated]
#                            1      1/15/2019    1/16/2019  [incarcerated]
#                            2      1/15/2019    1/16/2019  [incarcerated]
#                            3      1/15/2019    1/16/2019  [incarcerated]
# ALVARADO FRANCISCO         0     12/12/2018   12/12/2018  [incarcerated]
#                            1     12/12/2018   12/12/2018  [incarcerated]
#                            2     12/12/2018   12/12/2018  [incarcerated]
# ANDERSON HUNTER LEE        0       6/8/2016     6/8/2016  [incarcerated]
# ANDREWS JOSHUA LEE         0      1/25/2019    1/25/2019  [incarcerated]
#                            1      1/25/2019    1/25/2019  [incarcerated]
# ANGE CLYDE PHILLIP         0     11/14/2018   11/14/2018  [incarcerated]
#                            1     11/14/2018   11/14/2018  [incarcerated]
# ARCE JESUS                 0      8/27/2015    8/27/2015  [incarcerated]
#                            1      8/27/2015    8/27/2015  [incarcerated]
#                            2      8/27/2015    8/27/2015  [incarcerated]
# ...                                     ...          ...             ...
# WRIGHT RUSSELL LEE         11     1/13/2017    4/19/2017  [incarcerated]
#                            12     1/13/2017    8/24/2018  [incarcerated]
#                            13     1/13/2017     3/7/2017  [incarcerated]
#                            14     1/13/2017    1/13/2017  [incarcerated]
#                            15     1/13/2017    1/13/2017  [incarcerated]
#                            16     1/13/2017     3/7/2017  [incarcerated]
#                            17     1/13/2017     3/7/2017  [incarcerated]
#                            18     1/13/2017    1/13/2017  [incarcerated]
#                            19     1/13/2017    2/14/2017  [incarcerated]
#                            20     1/13/2017    2/14/2017  [incarcerated]
#                            21     1/13/2017     8/8/2017  [incarcerated]
#                            22     1/13/2017     8/8/2017  [incarcerated]
#                            23     1/13/2017     3/9/2017  [incarcerated]
#                            24     1/13/2017     3/9/2017  [incarcerated]
# YOUNG JAMES DAVID          0      1/17/2019    1/17/2019  [incarcerated]
#                            1      1/17/2019    1/17/2019  [incarcerated]
#                            2      1/17/2019    1/17/2019  [incarcerated]
#                            3      1/17/2019    1/17/2019  [incarcerated]
#                            4      1/17/2019    1/17/2019  [incarcerated]
#                            5      1/17/2019    1/17/2019  [incarcerated]
#                            6      1/17/2019    1/17/2019  [incarcerated]
#                            7      1/17/2019    1/17/2019  [incarcerated]
#                            8      1/17/2019    1/17/2019  [incarcerated]
#                            9      1/17/2019    1/17/2019  [incarcerated]
#                            10     1/17/2019    1/17/2019  [incarcerated]
#                            11     1/17/2019    1/17/2019  [incarcerated]
#                            12     1/17/2019    1/17/2019  [incarcerated]
#                            13     1/17/2019    1/17/2019  [incarcerated]
#                            14     1/17/2019    1/17/2019  [incarcerated]
#                            15     1/17/2019    1/17/2019  [incarcerated]
#
#                                                              Statute Description  \
# Name
# ALLEN CHRISTOPHER LEE      0                                     DELIVER COCAINE
#                            1                       M/S/D/P CS W/N 1000FT OF PARK
#                            2                       M/S/D/P CS W/N 1000FT OF PARK
#                            3                           MAINTN VEH/DWELL/PLACE CS
#                            4                          POSSESS DRUG PARAPHERNALIA
#                            5                                        SELL COCAINE
# ALSTON LADRRIOUS LAMONTE   0                          AID AND ABET ARMED ROBBERY
#                            1   FAILURE TO APPEAR ON MISDEMEANOR(M-BREAKING OR...
#                            2   FAILURE TO APPEAR ON MISDEMEANOR(MISDEMEANOR L...
#                            3                      OBTAIN PROPERTY FALSE PRETENSE
#                            4                        POSS CS PRISON/JAIL PREMISES
#                            5                       RECEIVE STOLEN GOODS/PROP (M)
#                            6                            RESISTING PUBLIC OFFICER
# ALSTON MARCELLAS ALEXANDER 0                         CONSP ROBBERY DANGRS WEAPON
#                            1                       ROBBERY WITH DANGEROUS WEAPON
# ALSTON SCOTT DELANTA       0                                 MISDEMEANOR LARCENY
#                            1                          MISDEMEANOR PROBATION VIOL
#                            2                          MISDEMEANOR PROBATION VIOL
#                            3                          MISDEMEANOR PROBATION VIOL
# ALVARADO FRANCISCO         0    TRUE BILL OF INDICTMENT(FIRST DEGREE KIDNAPPING)
#                            1   TRUE BILL OF INDICTMENT(FIRST DRGREE FORCIBLE ...
#                            2   TRUE BILL OF INDICTMENT(INDECENT LIBERTIES WIT...
# ANDERSON HUNTER LEE        0                        STATUTORY RAPE OF CHILD <=15
# ANDREWS JOSHUA LEE         0            FELONY PROBATION VIOLATION OUT OF COUNTY
#                            1            FELONY PROBATION VIOLATION OUT OF COUNTY
# ANGE CLYDE PHILLIP         0   FAILURE TO APPEAR ON MISDEMEANOR- MIS PROBATIO...
#                            1       MISDEMEANOR PROBATION VIOLATION OUT OF COUNTY
# ARCE JESUS                 0                                   FELONY CONSPIRACY
#                            1                                   FELONY CONSPIRACY
#                            2                             FIRST DEGREE KIDNAPPING
# ...                                                                          ...
# WRIGHT RUSSELL LEE         11                       POSSESS STOLEN MOTOR VEHICLE
#                            12                           RESISTING PUBLIC OFFICER
#                            13                      ROBBERY WITH DANGEROUS WEAPON
#                            14                      ROBBERY WITH DANGEROUS WEAPON
#                            15                      ROBBERY WITH DANGEROUS WEAPON
#                            16                      ROBBERY WITH DANGEROUS WEAPON
#                            17                      ROBBERY WITH DANGEROUS WEAPON
#                            18                      ROBBERY WITH DANGEROUS WEAPON
#                            19                                     SIMPLE ASSAULT
#                            20                                     SIMPLE ASSAULT
#                            21                                     SIMPLE ASSAULT
#                            22                                     SIMPLE ASSAULT
#                            23  TRUE BILL OF INDICTMENT (CONSP ROBBERY DANGRS ...
#                            24  TRUE BILL OF INDICTMENT (ROBBERY WITH DANGEROU...
# YOUNG JAMES DAVID          0   FAILURE TO APPEAR ON FELONY- FASIL TO HEED LIG...
#                            1   FAILURE TO APPEAR ON FELONY- FICT INFO TO OFFICER
#                            2               FAILURE TO APPEAR ON FELONY- ID THEFT
#                            3   FAILURE TO APPEAR ON FELONY- INJURY TO REAL PR...
#                            4   FAILURE TO APPEAR ON FELONY- POSS MAIRJ UP TO ...
#                            5       FAILURE TO APPEAR ON FELONY- POSS MARIJ PAPRA
#                            6   FAILURE TO APPEAR ON FELONY- RESIST PUBLIC OFF...
#                            7   FAILURE TO APPEAR ON FELONY- RESIST PUBLIC OFF...
#                            8   FAILURE TO APPEAR ON MISDEMEANOR- FIRST DEG TR...
#                            9          FAILURE TO APPEAR ON MISDEMEANOR- ID THEFT
#                            10      FAILURE TO APPEAR ON MISDEMEANOR- MIS LARCENY
#                            11      FAILURE TO APPEAR ON MISDEMEANOR- MIS LARCENY
#                            12  FAILURE TO APPEAR ON MISDEMEANOR- OBTAIN PROPE...
#                            13                                MISDEMEANOR LARCENY
#                            14                           RESISTING PUBLIC OFFICER
#                            15                           RESISTING PUBLIC OFFICER
#
#                               Bond Type    Bond Amount Court Docket  \
# Name
# ALLEN CHRISTOPHER LEE      0    SECURED          $0.00   18CRS53065
#                            1    SECURED     $30,000.00   18CRS53066
#                            2    SECURED    $100,000.00   18CRS53065
#                            3    SECURED          $0.00   18CRS53066
#                            4    SECURED          $0.00   18CRS53066
#                            5    SECURED          $0.00   18CRS53065
# ALSTON LADRRIOUS LAMONTE   0    SECURED    $200,000.00   18CR057750
#                            1    SECURED          $0.00   18CR053902
#                            2    SECURED          $0.00   18CR703606
#                            3    SECURED          $0.00   18CR057710
#                            4    SECURED      $1,500.00    18CR57756
#                            5    SECURED          $0.00   18CR057750
#                            6    SECURED          $0.00   18CR057750
# ALSTON MARCELLAS ALEXANDER 0    SECURED          $0.00   18CR056638
#                            1    SECURED    $125,000.00   18CR056638
# ALSTON SCOTT DELANTA       0    SECURED      $1,000.00    19CR50294
#                            1      [N/A]          $0.00    18CR56491
#                            2      [N/A]          $0.00    18CR54784
#                            3      [N/A]          $0.00    18CR56519
# ALVARADO FRANCISCO         0    SECURED          $0.00  18CRS056417
#                            1    SECURED  $1,000,000.00  18CRS056417
#                            2    SECURED          $0.00  18CRS056417
# ANDERSON HUNTER LEE        0    SECURED    $500,000.00    16CR54855
# ANDREWS JOSHUA LEE         0    SECURED          $0.00    17CRS3254
#                            1    SECURED      $5,000.00    17CRS3253
# ANGE CLYDE PHILLIP         0      [N/A]          $0.00   16CR050920
#                            1      [N/A]          $0.00   18CR002006
# ARCE JESUS                 0    NO BOND          $0.00   15CRS57459
#                            1    NO BOND          $0.00   15CRS57460
#                            2    NO BOND          $0.00   15CRS57459
# ...                                 ...            ...          ...
# WRIGHT RUSSELL LEE         11        NB          $0.00   17CR052886
#                            12        NB          $0.00   18CR056187
#                            13        NB          $0.00    16CR60314
#                            14   SECURED          $0.00  16CR 224329
#                            15   SECURED          $0.00   16CR 59725
#                            16   SECURED          $0.00   16CR 59726
#                            17   SECURED          $0.00    16CR60314
#                            18   SECURED  $1,000,000.00   16CR 60312
#                            19        NB          $0.00    17CR51077
#                            20        NB          $0.00    17CR51077
#                            21        NB          $0.00    17CR56032
#                            22        NB          $0.00    17CR56032
#                            23   NO BOND          $0.00     17CRS667
#                            24   NO BOND          $0.00     17CRS667
# YOUNG JAMES DAVID          0         NB          $0.00   18CRS50968
#                            1         NB          $0.00   18CRS50731
#                            2         NB          $0.00   18CRS50968
#                            3      [N/A]          $0.00   18CR051691
#                            4         NB          $0.00   18CRS50969
#                            5         NB          $0.00   18CRS50969
#                            6         NB          $0.00   18CRS50731
#                            7         NB          $0.00   18CRS50968
#                            8      [N/A]          $0.00   18CR051853
#                            9         NB          $0.00   18CRS50731
#                            10   SECURED          $0.00    18CR56614
#                            11   SECURED      $5,000.00    18CR51969
#                            12   SECURED          $0.00    18CR51969
#                            13        NB          $0.00    18CR52018
#                            14        NB          $0.00    18CR52018
#                            15   SECURED      $1,000.00   18CR058617
#
#                               Days in Jail/Charge Offender ID  Age  \
# Name
# ALLEN CHRISTOPHER LEE      0                  158      B34159   21
#                            1                  158      B34159   21
#                            2                  158      B34159   21
#                            3                  158      B34159   21
#                            4                  158      B34159   21
#                            5                  158      B34159   21
# ALSTON LADRRIOUS LAMONTE   0                   85         NaN  NaN
#                            1                   85         NaN  NaN
#                            2                   85         NaN  NaN
#                            3                   85         NaN  NaN
#                            4                   85         NaN  NaN
#                            5                   85         NaN  NaN
#                            6                   85         NaN  NaN
# ALSTON MARCELLAS ALEXANDER 0                  128         NaN  NaN
#                            1                  128         NaN  NaN
# ALSTON SCOTT DELANTA       0                   10      A20312   49
#                            1                    9      A20312   49
#                            2                    9      A20312   49
#                            3                    9      A20312   49
# ALVARADO FRANCISCO         0                   44         NaN  NaN
#                            1                   44         NaN  NaN
#                            2                   44         NaN  NaN
# ANDERSON HUNTER LEE        0                  961         NaN  NaN
# ANDREWS JOSHUA LEE         0                    0         NaN  NaN
#                            1                    0         NaN  NaN
# ANGE CLYDE PHILLIP         0                   72         NaN  NaN
#                            1                   72         NaN  NaN
# ARCE JESUS                 0                 1247         NaN  NaN
#                            1                 1247         NaN  NaN
#                            2                 1247         NaN  NaN
# ...                                           ...         ...  ...
# WRIGHT RUSSELL LEE         11                 646         NaN  NaN
#                            12                 154         NaN  NaN
#                            13                 689         NaN  NaN
#                            14                 742         NaN  NaN
#                            15                 742         NaN  NaN
#                            16                 689         NaN  NaN
#                            17                 689         NaN  NaN
#                            18                 742         NaN  NaN
#                            19                 710         NaN  NaN
#                            20                 710         NaN  NaN
#                            21                 535         NaN  NaN
#                            22                 535         NaN  NaN
#                            23                 687         NaN  NaN
#                            24                 687         NaN  NaN
# YOUNG JAMES DAVID          0                    8         NaN  NaN
#                            1                    8         NaN  NaN
#                            2                    8         NaN  NaN
#                            3                    8         NaN  NaN
#                            4                    8         NaN  NaN
#                            5                    8         NaN  NaN
#                            6                    8         NaN  NaN
#                            7                    8         NaN  NaN
#                            8                    8         NaN  NaN
#                            9                    8         NaN  NaN
#                            10                   8         NaN  NaN
#                            11                   8         NaN  NaN
#                            12                   8         NaN  NaN
#                            13                   8         NaN  NaN
#                            14                   8         NaN  NaN
#                            15                   8         NaN  NaN
#
#                               Date of Birth              Race Gender  \
# Name
# ALLEN CHRISTOPHER LEE      0     02/16/1997  African American   Male
#                            1     02/16/1997  African American   Male
#                            2     02/16/1997  African American   Male
#                            3     02/16/1997  African American   Male
#                            4     02/16/1997  African American   Male
#                            5     02/16/1997  African American   Male
# ALSTON LADRRIOUS LAMONTE   0            NaN               NaN    NaN
#                            1            NaN               NaN    NaN
#                            2            NaN               NaN    NaN
#                            3            NaN               NaN    NaN
#                            4            NaN               NaN    NaN
#                            5            NaN               NaN    NaN
#                            6            NaN               NaN    NaN
# ALSTON MARCELLAS ALEXANDER 0            NaN               NaN    NaN
#                            1            NaN               NaN    NaN
# ALSTON SCOTT DELANTA       0     08/15/1969  African American   Male
#                            1     08/15/1969  African American   Male
#                            2     08/15/1969  African American   Male
#                            3     08/15/1969  African American   Male
# ALVARADO FRANCISCO         0            NaN               NaN    NaN
#                            1            NaN               NaN    NaN
#                            2            NaN               NaN    NaN
# ANDERSON HUNTER LEE        0            NaN               NaN    NaN
# ANDREWS JOSHUA LEE         0            NaN               NaN    NaN
#                            1            NaN               NaN    NaN
# ANGE CLYDE PHILLIP         0            NaN               NaN    NaN
#                            1            NaN               NaN    NaN
# ARCE JESUS                 0            NaN               NaN    NaN
#                            1            NaN               NaN    NaN
#                            2            NaN               NaN    NaN
# ...                                     ...               ...    ...
# WRIGHT RUSSELL LEE         11           NaN               NaN    NaN
#                            12           NaN               NaN    NaN
#                            13           NaN               NaN    NaN
#                            14           NaN               NaN    NaN
#                            15           NaN               NaN    NaN
#                            16           NaN               NaN    NaN
#                            17           NaN               NaN    NaN
#                            18           NaN               NaN    NaN
#                            19           NaN               NaN    NaN
#                            20           NaN               NaN    NaN
#                            21           NaN               NaN    NaN
#                            22           NaN               NaN    NaN
#                            23           NaN               NaN    NaN
#                            24           NaN               NaN    NaN
# YOUNG JAMES DAVID          0            NaN               NaN    NaN
#                            1            NaN               NaN    NaN
#                            2            NaN               NaN    NaN
#                            3            NaN               NaN    NaN
#                            4            NaN               NaN    NaN
#                            5            NaN               NaN    NaN
#                            6            NaN               NaN    NaN
#                            7            NaN               NaN    NaN
#                            8            NaN               NaN    NaN
#                            9            NaN               NaN    NaN
#                            10           NaN               NaN    NaN
#                            11           NaN               NaN    NaN
#                            12           NaN               NaN    NaN
#                            13           NaN               NaN    NaN
#                            14           NaN               NaN    NaN
#                            15           NaN               NaN    NaN
#
#                               Custody Status
# Name
# ALLEN CHRISTOPHER LEE      0      In Custody
#                            1      In Custody
#                            2      In Custody
#                            3      In Custody
#                            4      In Custody
#                            5      In Custody
# ALSTON LADRRIOUS LAMONTE   0             NaN
#                            1             NaN
#                            2             NaN
#                            3             NaN
#                            4             NaN
#                            5             NaN
#                            6             NaN
# ALSTON MARCELLAS ALEXANDER 0             NaN
#                            1             NaN
# ALSTON SCOTT DELANTA       0      In Custody
#                            1      In Custody
#                            2      In Custody
#                            3      In Custody
# ALVARADO FRANCISCO         0             NaN
#                            1             NaN
#                            2             NaN
# ANDERSON HUNTER LEE        0             NaN
# ANDREWS JOSHUA LEE         0             NaN
#                            1             NaN
# ANGE CLYDE PHILLIP         0             NaN
#                            1             NaN
# ARCE JESUS                 0             NaN
#                            1             NaN
#                            2             NaN
# ...                                      ...
# WRIGHT RUSSELL LEE         11            NaN
#                            12            NaN
#                            13            NaN
#                            14            NaN
#                            15            NaN
#                            16            NaN
#                            17            NaN
#                            18            NaN
#                            19            NaN
#                            20            NaN
#                            21            NaN
#                            22            NaN
#                            23            NaN
#                            24            NaN
# YOUNG JAMES DAVID          0             NaN
#                            1             NaN
#                            2             NaN
#                            3             NaN
#                            4             NaN
#                            5             NaN
#                            6             NaN
#                            7             NaN
#                            8             NaN
#                            9             NaN
#                            10            NaN
#                            11            NaN
#                            12            NaN
#                            13            NaN
#                            14            NaN
#                            15            NaN
#
# [2583 rows x 14 columns]

# %%
# Convert final product to CSV file
final.to_csv('durham-data.csv')
